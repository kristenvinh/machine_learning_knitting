# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ast # Used to safely evaluate string representations of Python literals
import os

# %%
#Read in all the data from the processed chunks
output_dir = "../data_aquisition/processed_chunks"

import glob

# Find all the processed chunk CSV files
chunk_files = glob.glob(os.path.join(output_dir, "*.csv"))

# Read each chunk file into a list of dataframes
df_list = [pd.read_csv(f) for f in chunk_files]

# Concatenate all dataframes in the list into one
df = pd.concat(df_list, ignore_index=True)

# %%
#Look at the first few rows of the DataFrame
df.head()
# Out:
#                           Name           Designer     ID  \
# 0         #08 Cropped Cardigan    Faye Rubenstein  18699
# 1                   Maybelline     Louisa Harding  18700
# 2                          Flo     Kim Hargreaves  18721
# 3  Baby's First Merino Sweater  Morehouse Designs  18725
# 4           Honeycomb Cardigan  Rosemary Drysdale  18779
#
#                                                  URL   Free  \
# 0  https://www.ravelry.com/patterns/library/08-cr...  False
# 1  https://www.ravelry.com/patterns/library/maybe...  False
# 2       https://www.ravelry.com/patterns/library/flo  False
# 3  https://www.ravelry.com/patterns/library/babys...  False
# 4  https://www.ravelry.com/patterns/library/honey...  False
#
#                                                Photo     Craft  \
# 0  https://images4-a.ravelrycache.com/uploads/rrr...  Knitting
# 1  https://images4-a.ravelrycache.com/uploads/kew...  Knitting
# 2  https://images4-f.ravelrycache.com/flickr/4/1/...  Knitting
# 3  https://images4-a.ravelrycache.com/uploads/Cha...  Knitting
# 4  https://images4-f.ravelrycache.com/flickr/3/2/...  Knitting
#
#                                           Attributes  Gauge  \
# 0  ['female', 'adult', 'petite', 'textured', 'sad...   28.0
# 1  ['female', 'adult', 'fitted', 'seamed', 'shawl...   22.0
# 2  ['female', 'adult', 'seamed', 'ruffles', 'butt...   28.0
# 3  ['unisex', 'baby', 'ribbed', 'textured', 'crew...    NaN
# 4  ['female', 'adult', 'cables', 'ribbed', 'seame...   20.0
#
#    Difficulty Average Downloadable  Gauge Divisor  \
# 0            3.666667         True            4.0
# 1            0.000000        False            4.0
# 2            4.076923        False            4.0
# 3            2.600000        False            NaN
# 4            0.000000        False            4.0
#
#                                 Gauge Pattern Pattern Type Yarn Weight  \
# 0                            textured stitch      cardigan          DK
# 1  over pattern using US 6 (4.00 mm) needles.     cardigan          DK
# 2                                         NaN     cardigan   Fingering
# 3                                         NaN         baby     Worsted
# 4                                     2x2 rib     cardigan        Aran
#
#    Projects Count  Rating Average  \
# 0               8        0.000000
# 1               3        0.000000
# 2              58        4.583333
# 3              16        4.600000
# 4               4        0.000000
#
#                                      Sizes Available  \
# 0     Bust:  30 (33, 36, 40)"/76 (84, 91.5, 101.5)cm
# 1                                     Small (Medium)
# 2  XS (32); S (34); M (36); L (38); XL (40); XXL ...
# 3                                                NaN
# 4                                                NaN
#
#                                               Photos
# 0  [{'id': 10982458, 'sort_order': 1, 'user_id': ...
# 1  [{'id': 823680, 'sort_order': 1, 'user_id': 31...
# 2  [{'id': 10573288, 'sort_order': 1, 'user_id': ...
# 3  [{'id': 331059, 'sort_order': 1, 'user_id': 64...
# 4  [{'id': 5850319, 'sort_order': 1, 'user_id': 9...

# %%
#Look at the last few rows of the DataFrame
df.tail()
# Out:
#               Name       Designer       ID  \
# 39792       Meader     Åsa Buchta  7352049
# 39793       Yonagi  Hiromi Otsuru  7354596
# 39794     Sazanami  Megumi Sawada  7354602
# 39795        Ayaka  Linda Marveng  7355593
# 39796  Patch Me Up   Candi Jensen  7357106
#
#                                                      URL   Free  \
# 39792    https://www.ravelry.com/patterns/library/meader  False
# 39793    https://www.ravelry.com/patterns/library/yonagi  False
# 39794  https://www.ravelry.com/patterns/library/sazan...  False
# 39795   https://www.ravelry.com/patterns/library/ayaka-4  False
# 39796  https://www.ravelry.com/patterns/library/patch...   True
#
#                                                    Photo     Craft  \
# 39792  https://images4-a.ravelrycache.com/uploads/mjk...  Knitting
# 39793  https://images4-a.ravelrycache.com/uploads/ami...  Knitting
# 39794  https://images4-a.ravelrycache.com/uploads/ami...  Knitting
# 39795  https://images4-a.ravelrycache.com/uploads/lin...  Knitting
# 39796  https://images4-a.ravelrycache.com/uploads/amy...  Knitting
#
#                                               Attributes  Gauge  \
# 39792  ['adult', 'plus', 'lace', 'seamed', 'v-neck', ...   15.0
# 39793  ['adult', 'ribbed', 'top-down', 'cropped', 'wo...   22.0
# 39794  ['adult', 'cables', 'crew-neck', 'buttoned', '...   18.0
# 39795  ['female', 'adult', 'plus', 'cables', 'eyelets...   25.0
# 39796  ['unisex', 'adult', 'oversized', 'seamed', 'bo...   20.0
#
#        Difficulty Average Downloadable  Gauge Divisor          Gauge Pattern  \
# 39792                 0.0         True            4.0         Pattern stitch
# 39793                 0.0        False            4.0  in Stockinette stitch
# 39794                 0.0        False            4.0  in Stockinette stitch
# 39795                 0.0         True            4.0                  St st
# 39796                 0.0         True            4.0            Stockinette
#
#       Pattern Type Yarn Weight  Projects Count  Rating Average  \
# 39792     cardigan       Bulky               5             0.0
# 39793     cardigan       Sport               6             0.0
# 39794     cardigan          DK               3             0.0
# 39795     cardigan       Sport               7             0.0
# 39796     cardigan     Worsted               6             0.0
#
#                                          Sizes Available  \
# 39792  Bust (with buttonbands overlapped): (38½, 42¾,...
# 39793  Finished bust measurements: 1 (2, 3, 4) (5, 6,...
# 39794  Finished bust measurements: 1 (2, 3, 4) (5, 6,...
# 39795                        1 (2, 3, 4, 5) (6, 7, 8, 9)
# 39796                    XS[S, M, L, 1X, 2X, 3X, 4X, 5X]
#
#                                                   Photos
# 39792  [{'id': 131120686, 'sort_order': 1, 'user_id':...
# 39793  [{'id': 131374067, 'sort_order': 1, 'user_id':...
# 39794  [{'id': 131374122, 'sort_order': 1, 'user_id':...
# 39795  [{'id': 131460405, 'sort_order': 1, 'user_id':...
# 39796  [{'id': 131580801, 'sort_order': 1, 'user_id':...

# %%
#Get a summary of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39797 entries, 0 to 39796
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                39797 non-null  object
#  1   Designer            39797 non-null  object
#  2   ID                  39797 non-null  int64
#  3   URL                 39797 non-null  object
#  4   Free                39796 non-null  object
#  5   Photo               39797 non-null  object
#  6   Craft               39793 non-null  object
#  7   Attributes          39797 non-null  object
#  8   Gauge               37341 non-null  float64
#  9   Difficulty Average  39793 non-null  float64
#  10  Downloadable        39796 non-null  object
#  11  Gauge Divisor       37549 non-null  float64
#  12  Gauge Pattern       32392 non-null  object
#  13  Pattern Type        39792 non-null  object
#  14  Yarn Weight         38817 non-null  object
#  15  Projects Count      39797 non-null  int64
#  16  Rating Average      39793 non-null  float64
#  17  Sizes Available     34796 non-null  object
#  18  Photos              39793 non-null  object
# dtypes: float64(4), int64(2), object(13)
# memory usage: 5.8+ MB

# %%
#Get a count of unique values in each column -- based on this, I can see that Sizes Available isn't going to be very useful since it has a lot of unique values, but, it will be useful when it comes to the final app since it tells us what sizes are available for each pattern
df.nunique()
# Out:
# Name                  37138
# Designer               6015
# ID                    39797
# URL                   39797
# Free                      2
# Photo                 39796
# Craft                     1
# Attributes            38453
# Gauge                   161
# Difficulty Average     4364
# Downloadable              2
# Gauge Divisor             3
# Gauge Pattern          9305
# Pattern Type             20
# Yarn Weight              15
# Projects Count         1205
# Rating Average         3023
# Sizes Available       19491
# Photos                39793
# dtype: int64

# %%
#Check for missing values -- I'm not sure yet if I'm going to use Gauge as a feature, so I might need to do something about the missing values in that column later
df.isnull().sum()
# Out:
# Name                     0
# Designer                 0
# ID                       0
# URL                      0
# Free                     1
# Photo                    0
# Craft                    4
# Attributes               0
# Gauge                 2456
# Difficulty Average       4
# Downloadable             1
# Gauge Divisor         2248
# Gauge Pattern         7405
# Pattern Type             5
# Yarn Weight            980
# Projects Count           0
# Rating Average           4
# Sizes Available       5001
# Photos                   4
# dtype: int64

# %%
# Use .isin() to check for multiple values at once
# Get only pullovers and cardigans
df = df[df['Pattern Type'].isin(['pullover', 'cardigan'])]

# %%
df['Attributes_list'] = df['Attributes'].fillna('[]').apply(ast.literal_eval)

# Create a new DataFrame with dummy variables from the 'Attributes_list'
# We first explode the lists to have one attribute per row, then get dummies
# and finally group by the original index and sum to get the one-hot encoding
attributes_dummies = df['Attributes_list'].explode().str.get_dummies().groupby(level=0).sum()

# Add a prefix to the attribute columns to avoid potential column name conflicts
attributes_dummies = attributes_dummies.add_prefix('attr_')

# Concatenate the new dummy variables DataFrame with the original DataFrame
df_expanded = pd.concat([df, attributes_dummies], axis=1)

# Drop the intermediate 'Attributes_list' and original 'Attributes' columns
df_expanded = df_expanded.drop(['Attributes', 'Attributes_list'], axis=1)

# %%
# Now, filter the DataFrame to include only rows where 'attr_adult' is True
df_expanded = df_expanded[df_expanded['attr_adult'] == True]

df_expanded.shape
# Out:
# (24816, 233)

# %%
df['Pattern Type'].value_counts()
# Out:
# Pattern Type
# pullover    16712
# cardigan    13942
# Name: count, dtype: int64

# %%
   # Get all the columns that start with 'attr_'
attribute_columns = [col for col in df_expanded.columns if col.startswith('attr_')]

# Calculate the sum of each attribute column
attribute_counts = df_expanded[attribute_columns].sum()

# Create a new DataFrame from the attribute counts
attribute_counts_df = pd.DataFrame(attribute_counts, columns=['Count'])

# Reset the index to make the attribute names a column
attribute_counts_df = attribute_counts_df.reset_index().rename(columns={'index': 'Attribute'})

# Sort the attributes by count in descending order
attribute_counts_df = attribute_counts_df.sort_values(by='Count', ascending=False)

# Remove the 'attr_' prefix from the 'Attribute' column
attribute_counts_df['Attribute'] = attribute_counts_df['Attribute'].str.replace('attr_', '')
attribute_counts_df.to_csv('attribute_counts.csv', index=False)
